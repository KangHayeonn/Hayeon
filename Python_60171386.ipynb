# %% [markdown]
# <a href="https://colab.research.google.com/github/KangHayeonn/Hayeon/blob/master/Python_60171386.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 기상청에 따른 드레스 코드

# %%
! pip install beautifulsoup4

# %%
from google.colab import files
from urllib import request
from bs4 import BeautifulSoup
import pandas as pd

f = open("weather.csv", "w")
f.write("도시,날짜,날씨,최저기온,최고기온\n")

target = request.urlopen('http://www.weather.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108')
soup = BeautifulSoup(target, "html.parser")

for location in soup.select("location"):
    city = location.select_one("city").string

    for data in location.select("data"):
      date = data.select_one("tmef").string
      weather = data.select_one("wf").string
      tmn = data.select_one("tmn").string
      tmx = data.select_one("tmx").string
      f.write(city + "," + date + "," + weather + "," + tmn + "," + tmx + "\n")
    
files.download("weather.csv")
f.close()

# %% [markdown]
# [ 기상청 지역 ]
#
# 서울, 인천, 수원, 파주, 이천, 평택, 춘천, 원주, 강릉, 대전, 세종, 홍성, 청주, 충주, 영동, 광주,목포, 여수, 순천, 광양, 나주, 전주, 군산, 정읍, 남원, 고창, 무주, 부산, 울산, 창원, 진주, 거창, 통영, 대구, 안동, 포항, 경주 , 울진, 울릉도, 제주, 서귀포

# %%
def result_dresscode(target):
      for i in range(0,13):
        data_date = str(data.iloc[i:i+1, 1:2])  # 특정 날짜의 행만 읽어옴
        
        if target.date in data_date :
          data_weather = str(data.iloc[i:i+1, 2:3])  # 위의 날짜의 날씨를 불러옴
          data_tmn = data['최저기온'].head(1)           # 최저기온을 불러옴
          data_tmx = data['최고기온'].head(1)           # 최고기온을 불러옴
          data_avg = int((data_tmn + data_tmx) / 2)
          print()
          print('{}님 {}에는' .format(target.name, target.date))

          if data_avg <= 8 :
            print('패딩 및 코트같은 겨울용 외투를 챙기세요!')
            if '흐림' in data_weather or '흐리고 비' in data_weather:
              print('우산도 챙기세요!')
            return 
          elif 8 < data_avg <= 14 :
            print('쌀쌀한 날씨에 대비한 얇은 겉옷 및 가디건을 추천합니다!')
            if '흐림' in data_weather or '흐리고 비' in data_weather:
                print('우산도 챙기세요!')
            return 
          elif 14 < data_avg <= 21 :
            print('소재가 두껍지 않은 긴팔추천합니다!')
            if '흐림' in data_weather or '흐리고 비' in data_weather:
                print('우산도 챙기세요!')
            return 
          else : 
            print('반팔과 같은 여름용 옷을 입으세요!')
            if '흐림' in data_weather or '흐리고 비' in data_weather:
                print('우산도 챙기세요!')
            return 
        else:
          continue
      print()
      print(target.date , " 날짜는 해당 기상청 자료에 없습니다.")
      
      return

# %%
import pandas as pd

data = pd.read_csv("weather.csv", sep=",")

class DressCode:
  def __init__(self, name, city, gender, date):
    self.name = name
    self.city = city
    self.gender = gender
    self.date = date

    if self.city == '서울' :
      data_city = data[data['도시']=='서울']
      print()
      print(data_city)
      result_dresscode(self)

    elif self.city == '인천' :
      data_city = data[data['도시']=='인천']
      print()
      print(data_city)
      result_dresscode(self)

    elif self.city == '수원' : 
      data_city = data[data['도시']=='수원']
      print()
      print(data_city)
      result_dresscode(self)

    elif self.city == '파주' : 
      data_city = data[data['도시']=='파주']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '이천' : 
      data_city = data[data['도시']=='이천']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '평택' : 
      data_city = data[data['도시']=='평택']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '춘천' : 
      data_city = data[data['도시']=='춘천']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '원주' : 
      data_city = data[data['도시']=='원주']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '강릉' : 
      data_city = data[data['도시']=='강릉']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '대전' : 
      data_city = data[data['도시']=='대전']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '세종' : 
      data_city = data[data['도시']=='세종']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '홍성' : 
      data_city = data[data['도시']=='홍성']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '청주' : 
      data_city = data[data['도시']=='청주']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '충주' : 
      data_city = data[data['도시']=='충주']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '영동' : 
      data_city = data[data['도시']=='영동']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '광주' : 
      data_city = data[data['도시']=='광주']
      print()
      print(data_city)
      result_dresscode(self)
       
    elif self.city == '목포' : 
      data_city = data[data['도시']=='목포']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '여수' : 
      data_city = data[data['도시']=='여수']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '순천' : 
      data_city = data[data['도시']=='순천']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '광양' : 
      data_city = data[data['도시']=='광양']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '나주' : 
      data_city = data[data['도시']=='나주']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '전주' : 
      data_city = data[data['도시']=='전주']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '군산' : 
      data_city = data[data['도시']=='군산']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '정읍' : 
      data_city = data[data['도시']=='정읍']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '남원' : 
      data_city = data[data['도시']=='남원']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '고창' : 
      data_city = data[data['도시']=='고창']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '무주' : 
      data_city = data[data['도시']=='무주']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '부산' : 
      data_city = data[data['도시']=='부산']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '울산' : 
      data_city = data[data['도시']=='울산']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '창원' : 
      data_city = data[data['도시']=='창원']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '진주' : 
      data_city = data[data['도시']=='진주']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '거창' : 
      data_city = data[data['도시']=='거창']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '통영' : 
      data_city = data[data['도시']=='통영']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '대구' : 
      data_city = data[data['도시']=='대구']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '안동' : 
      data_city = data[data['도시']=='안동']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '포항' : 
      data_city = data[data['도시']=='포항']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '경주' : 
      data_city = data[data['도시']=='경주']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '울진' : 
      data_city = data[data['도시']=='울진']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '울릉도' : 
      data_city = data[data['도시']=='울릉도']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '제주' : 
      data_city = data[data['도시']=='제주']
      print()
      print(data_city)
      result_dresscode(self)
      
    elif self.city == '서귀포' : 
      data_city = data[data['도시']=='서귀포']
      print()
      print(data_city)
      result_dresscode(self)
      
    else:
      print()
      print(self.city , " 지역은 해당 기상청 자료에 없습니다.")

  def __del__(self): # 소멸자 함수
    print()

# %%
import time

my_information = {'my_name': '', 'my_city': '', 'my_gender': '', 'my_date': ''}

print('# 기상청에서 알려주는 드레스코드 프로그램 #')

checkbtn = 0

while checkbtn !=3 :
  print()
  checkbtn = int(input('실행하실 버튼 번호를 입력해주세요. (1= 정보입력 2= 드레스코드확인 3= 종료) >> '))

  if checkbtn  ==1 :
    my_name = input('이름을 입력하시오 (ex. 강하연) >> ')
    my_city = input('사는 곳을 입력하시오(ex. 서울 인천 평택 등등) >> ')
    my_gender = input('성별을 입력하시오 (ex. 여) >> ')
    my_date = input('외출하실 날짜를 입력하시오 (ex. 2021-06-08) >> ')
    
    my_information['my_name'] = my_name
    my_information['my_city'] = my_city
    my_information['my_gender'] = my_gender
    my_information['my_date'] = my_date

    print(my_information)
  
  if checkbtn ==2:
    try: 
      if my_name=='' or my_city=='' or my_gender=='' or my_date=='':
        예외.발생()
    except Exception as e:
      print('입력된 정보값이 잘못되었습니다. 다시 입력해주시기 바랍니다.')
    else:
      print('드레스코드 뽑는 중입니다...')
      time.sleep(3)
      DressCode(my_name,my_city,my_gender,my_date)

if checkbtn == 3:
  print()
  print('프로그램을 종료합니다. 이용해주셔서 감사합니다. ^_^')
# Out:
# # 기상청에서 알려주는 드레스코드 프로그램 #
#
# 실행하실 버튼 번호를 입력해주세요. (1= 정보입력 2= 드레스코드확인 3= 종료) >> 1
# 이름을 입력하시오 (ex. 강하연) >> 강하연
# 사는 곳을 입력하시오(ex. 서울 인천 평택 등등) >> 서울
# 성별을 입력하시오 (ex. 여) >> 여
# 외출하실 날짜를 입력하시오 (ex. 2021-06-08) >> 2021-06-18
# {'my_name': '강하연', 'my_city': '서울', 'my_gender': '여', 'my_date': '2021-06-18'}
#
# 실행하실 버튼 번호를 입력해주세요. (1= 정보입력 2= 드레스코드확인 3= 종료) >> 2
# 드레스코드 뽑는 중입니다...
#
#     도시                날짜     날씨  최저기온  최고기온
# 0   서울  2021-06-14 00:00   구름많음    21    31
# 1   서울  2021-06-14 12:00   구름많음    21    31
# 2   서울  2021-06-15 00:00   구름많음    20    30
# 3   서울  2021-06-15 12:00     맑음    20    30
# 4   서울  2021-06-16 00:00   구름많음    20    30
# 5   서울  2021-06-16 12:00   구름많음    20    30
# 6   서울  2021-06-17 00:00  흐리고 비    21    26
# 7   서울  2021-06-17 12:00  흐리고 비    21    26
# 8   서울  2021-06-18 00:00     흐림    20    27
# 9   서울  2021-06-18 12:00     맑음    20    27
# 10  서울  2021-06-19 00:00     맑음    19    28
# 11  서울  2021-06-20 00:00     맑음    19    28
# ...
